# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
# Convert nominal data into numerical values
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error','friedman_mse','absolute_error','poisson'],
              'max_features': ['sqrt','log2',None],
              'splitter':['best','random']} 

# GridSearch for Decision Tree Regressor
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
   
# fitting the model for grid search 
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test) 
   
# print classification report 
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)

print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_features': 'log2', 'splitter': 'random'}: 0.7257958494594806

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.003668      0.000291         0.001657        0.000295
# 1        0.002903      0.000377         0.001469        0.000141
# 2        0.003194      0.000544         0.001467        0.000220
# 3        0.002886      0.000402         0.001529        0.000160
# 4        0.003810      0.000387         0.001408        0.000183
# 5        0.004011      0.001368         0.002058        0.001073
# 6        0.003292      0.000314         0.002535        0.001970
# 7        0.003151      0.000374         0.001988        0.000561
# 8        0.003535      0.001226         0.001345        0.000200
# 9        0.002764      0.000455         0.001370        0.000402
# 10       0.004503      0.000805         0.001602        0.000351
# 11       0.002976      0.000420         0.001529        0.000323
# 12       0.011681      0.001408         0.001423        0.000176
# 13       0.010781      0.002617         0.001510        0.000348
# 14       0.014371      0.001175         0.001419        0.000247
# 15       0.010863      0.003495         0.001448        0.000830
# 16       0.019302      0.003182         0.001564        0.000717
# 17       0.014153      0.002120         0.001173        0.000146
# 18       0.003958      0.000980         0.001544        0.000515
# 19       0.003716      0.000243         0.001545        0.000225
# 20       0.004637      0.000546         0.001551        0.000159
# 21       0.003355      0.000435         0.001639        0.000283
# 22       0.005335      0.001095         0.001252        0.000190
# 23       0.003201      0.000320         0.001287        0.000233
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4    squared_error               None           best
# 5    squared_error               None         random
# 6     friedman_mse               sqrt           best
# 7     friedman_mse               sqrt         random
# 8     friedman_mse               log2           best
# 9     friedman_mse               log2         random
# 10    friedman_mse               None           best
# 11    friedman_mse               None         random
# 12  absolute_error               sqrt           best
# 13  absolute_error               sqrt         random
# 14  absolute_error               log2           best
# 15  absolute_error               log2         random
# 16  absolute_error               None           best
# 17  absolute_error               None         random
# 18         poisson               sqrt           best
# 19         poisson               sqrt         random
# 20         poisson               log2           best
# 21         poisson               log2         random
# 22         poisson               None           best
# 23         poisson               None         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.677063
# 1   {'criterion': 'squared_error', 'max_features':...           0.568033
# 2   {'criterion': 'squared_error', 'max_features':...           0.674399
# 3   {'criterion': 'squared_error', 'max_features':...           0.490495
# 4   {'criterion': 'squared_error', 'max_features':...           0.693241
# 5   {'criterion': 'squared_error', 'max_features':...           0.590896
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.675272
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.522005
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.619461
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.541962
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.687785
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.628445
# 12  {'criterion': 'absolute_error', 'max_features'...           0.646986
# 13  {'criterion': 'absolute_error', 'max_features'...           0.373979
# 14  {'criterion': 'absolute_error', 'max_features'...           0.623379
# 15  {'criterion': 'absolute_error', 'max_features'...           0.622914
# 16  {'criterion': 'absolute_error', 'max_features'...           0.628138
# 17  {'criterion': 'absolute_error', 'max_features'...           0.677380
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...           0.709141
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...           0.596244
# 20  {'criterion': 'poisson', 'max_features': 'log2...           0.694768
# 21  {'criterion': 'poisson', 'max_features': 'log2...           0.621664
# 22  {'criterion': 'poisson', 'max_features': None,...           0.696287
# 23  {'criterion': 'poisson', 'max_features': None,...           0.635492
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.523040           0.331426           0.562209
# 1            0.583665           0.577545           0.483797
# 2            0.323608           0.676411           0.626156
# 3            0.615733           0.645803           0.733356
# 4            0.475168           0.750248           0.633401
# 5            0.693723           0.727217           0.487898
# 6            0.526953           0.662221           0.575362
# 7            0.690701           0.511904           0.390562
# 8            0.646818           0.717570           0.610630
# 9            0.567487           0.676000           0.557122
# 10           0.495751           0.792924           0.629899
# 11           0.681233           0.684311           0.652063
# 12           0.659864           0.673958           0.664641
# 13           0.645187           0.668313           0.488151
# 14           0.585888           0.331536           0.683442
# 15           0.703331           0.690838           0.625327
# 16           0.527965           0.679740           0.608691
# 17           0.613348           0.778429           0.514292
# 18           0.537792           0.664241           0.554743
# 19           0.602492           0.669839           0.397434
# 20           0.637490           0.594067           0.268071
# 21           0.432190           0.487264           0.574264
# 22           0.426424           0.722790           0.595184
# 23           0.624548           0.610411           0.393993
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.423083         0.503364        0.118346               24
# 1            0.641327         0.570874        0.050522               18
# 2            0.629696         0.586054        0.132936               14
# 3            0.630647         0.623207        0.077932                9
# 4            0.665231         0.643458        0.092498                6
# 5            0.675336         0.635014        0.086213                8
# 6            0.480208         0.584003        0.075566               15
# 7            0.658960         0.554826        0.108819               20
# 8            0.684010         0.655698        0.040132                2
# 9            0.603529         0.589220        0.047899               13
# 10           0.655625         0.652397        0.095973                3
# 11           0.588864         0.646983        0.035535                5
# 12           0.605535         0.650197        0.023965                4
# 13           0.459659         0.527058        0.112603               23
# 14           0.639538         0.572757        0.124606               17
# 15           0.650950         0.658672        0.033103                1
# 16           0.629738         0.614854        0.049388               11
# 17           0.620735         0.640837        0.086534                7
# 18           0.632070         0.619597        0.064907               10
# 19           0.459762         0.545154        0.100556               21
# 20           0.659047         0.570689        0.154783               19
# 21           0.543283         0.531733        0.066206               22
# 22           0.617535         0.611644        0.104048               12
# 23           0.612181         0.575325        0.091119               16

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 45
# BMI: 23.5
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[19496.71917]

# %%
table=pd.DataFrame.from_dict(re)
best_r = table['mean_test_score'].max()
best_r
# Out:
# 0.6586718073641936

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.003668      0.000291         0.001657        0.000295
# 1        0.002903      0.000377         0.001469        0.000141
# 2        0.003194      0.000544         0.001467        0.000220
# 3        0.002886      0.000402         0.001529        0.000160
# 4        0.003810      0.000387         0.001408        0.000183
# 5        0.004011      0.001368         0.002058        0.001073
# 6        0.003292      0.000314         0.002535        0.001970
# 7        0.003151      0.000374         0.001988        0.000561
# 8        0.003535      0.001226         0.001345        0.000200
# 9        0.002764      0.000455         0.001370        0.000402
# 10       0.004503      0.000805         0.001602        0.000351
# 11       0.002976      0.000420         0.001529        0.000323
# 12       0.011681      0.001408         0.001423        0.000176
# 13       0.010781      0.002617         0.001510        0.000348
# 14       0.014371      0.001175         0.001419        0.000247
# 15       0.010863      0.003495         0.001448        0.000830
# 16       0.019302      0.003182         0.001564        0.000717
# 17       0.014153      0.002120         0.001173        0.000146
# 18       0.003958      0.000980         0.001544        0.000515
# 19       0.003716      0.000243         0.001545        0.000225
# 20       0.004637      0.000546         0.001551        0.000159
# 21       0.003355      0.000435         0.001639        0.000283
# 22       0.005335      0.001095         0.001252        0.000190
# 23       0.003201      0.000320         0.001287        0.000233
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4    squared_error               None           best
# 5    squared_error               None         random
# 6     friedman_mse               sqrt           best
# 7     friedman_mse               sqrt         random
# 8     friedman_mse               log2           best
# 9     friedman_mse               log2         random
# 10    friedman_mse               None           best
# 11    friedman_mse               None         random
# 12  absolute_error               sqrt           best
# 13  absolute_error               sqrt         random
# 14  absolute_error               log2           best
# 15  absolute_error               log2         random
# 16  absolute_error               None           best
# 17  absolute_error               None         random
# 18         poisson               sqrt           best
# 19         poisson               sqrt         random
# 20         poisson               log2           best
# 21         poisson               log2         random
# 22         poisson               None           best
# 23         poisson               None         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.677063
# 1   {'criterion': 'squared_error', 'max_features':...           0.568033
# 2   {'criterion': 'squared_error', 'max_features':...           0.674399
# 3   {'criterion': 'squared_error', 'max_features':...           0.490495
# 4   {'criterion': 'squared_error', 'max_features':...           0.693241
# 5   {'criterion': 'squared_error', 'max_features':...           0.590896
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.675272
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.522005
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.619461
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.541962
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.687785
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.628445
# 12  {'criterion': 'absolute_error', 'max_features'...           0.646986
# 13  {'criterion': 'absolute_error', 'max_features'...           0.373979
# 14  {'criterion': 'absolute_error', 'max_features'...           0.623379
# 15  {'criterion': 'absolute_error', 'max_features'...           0.622914
# 16  {'criterion': 'absolute_error', 'max_features'...           0.628138
# 17  {'criterion': 'absolute_error', 'max_features'...           0.677380
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...           0.709141
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...           0.596244
# 20  {'criterion': 'poisson', 'max_features': 'log2...           0.694768
# 21  {'criterion': 'poisson', 'max_features': 'log2...           0.621664
# 22  {'criterion': 'poisson', 'max_features': None,...           0.696287
# 23  {'criterion': 'poisson', 'max_features': None,...           0.635492
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.523040           0.331426           0.562209
# 1            0.583665           0.577545           0.483797
# 2            0.323608           0.676411           0.626156
# 3            0.615733           0.645803           0.733356
# 4            0.475168           0.750248           0.633401
# 5            0.693723           0.727217           0.487898
# 6            0.526953           0.662221           0.575362
# 7            0.690701           0.511904           0.390562
# 8            0.646818           0.717570           0.610630
# 9            0.567487           0.676000           0.557122
# 10           0.495751           0.792924           0.629899
# 11           0.681233           0.684311           0.652063
# 12           0.659864           0.673958           0.664641
# 13           0.645187           0.668313           0.488151
# 14           0.585888           0.331536           0.683442
# 15           0.703331           0.690838           0.625327
# 16           0.527965           0.679740           0.608691
# 17           0.613348           0.778429           0.514292
# 18           0.537792           0.664241           0.554743
# 19           0.602492           0.669839           0.397434
# 20           0.637490           0.594067           0.268071
# 21           0.432190           0.487264           0.574264
# 22           0.426424           0.722790           0.595184
# 23           0.624548           0.610411           0.393993
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.423083         0.503364        0.118346               24
# 1            0.641327         0.570874        0.050522               18
# 2            0.629696         0.586054        0.132936               14
# 3            0.630647         0.623207        0.077932                9
# 4            0.665231         0.643458        0.092498                6
# 5            0.675336         0.635014        0.086213                8
# 6            0.480208         0.584003        0.075566               15
# 7            0.658960         0.554826        0.108819               20
# 8            0.684010         0.655698        0.040132                2
# 9            0.603529         0.589220        0.047899               13
# 10           0.655625         0.652397        0.095973                3
# 11           0.588864         0.646983        0.035535                5
# 12           0.605535         0.650197        0.023965                4
# 13           0.459659         0.527058        0.112603               23
# 14           0.639538         0.572757        0.124606               17
# 15           0.650950         0.658672        0.033103                1
# 16           0.629738         0.614854        0.049388               11
# 17           0.620735         0.640837        0.086534                7
# 18           0.632070         0.619597        0.064907               10
# 19           0.459762         0.545154        0.100556               21
# 20           0.659047         0.570689        0.154783               19
# 21           0.543283         0.531733        0.066206               22
# 22           0.617535         0.611644        0.104048               12
# 23           0.612181         0.575325        0.091119               16

# %%
best_r = table['mean_test_score'].max()
best_r
# Out:
# 0.6586718073641936
